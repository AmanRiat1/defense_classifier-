# %%
import pandas as pd
import basketball_reference_scraper
from basketball_reference_scraper.players import get_stats, get_game_logs

# %%
players.columns
# Out:
# Index(['Name', 'Year Drafted', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%',
#        '3P Made', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB',
#        'AST', 'STL', 'BLK', 'TOV', 'EFF'],
#       dtype='object')

# %%
players = pd.read_csv('nba_rookies.csv')
players = players.dropna()
grouped_players = players.groupby('Year Drafted')
indexes = grouped_players.groups[1999.0]

sample_name = players.iloc[indexes]['Name'].iloc[0]
sample_year = players.iloc[indexes]['Year Drafted'].iloc[0]

# %%
sample_name
# Out:
# 'Elton Brand'

# %%
sample_player_stats = get_stats(sample_name, stat_type='ADVANCED', playoffs=False, career=False)

# %%
sample_player_stats
# Out:
#      SEASON   AGE TEAM LEAGUE POS     G      MP   PER    TS%   3PAr  ...  \
# 0   1999-00  20.0  CHI    NBA  PF  81.0  2999.0  20.6  0.528  0.002  ...
# 1   2000-01  21.0  CHI    NBA  PF  74.0  2906.0  20.4  0.524  0.002  ...
# 2   2001-02  22.0  LAC    NBA  PF  80.0  3020.0  23.6  0.586  0.000  ...
# 3   2002-03  23.0  LAC    NBA  PF  62.0  2454.0  21.7  0.543  0.001  ...
# 4   2003-04  24.0  LAC    NBA  PF  69.0  2670.0  23.2  0.567  0.001  ...
# 5   2004-05  25.0  LAC    NBA  PF  81.0  3001.0  22.4  0.554  0.002  ...
# 6   2005-06  26.0  LAC    NBA  PF  79.0  3099.0  26.5  0.580  0.002  ...
# 7   2006-07  27.0  LAC    NBA  PF  80.0  3077.0  23.1  0.581  0.001  ...
# 8   2007-08  28.0  LAC    NBA  PF   8.0   274.0  18.0  0.523  0.000  ...
# 9   2008-09  29.0  PHI    NBA  PF  29.0   920.0  14.6  0.484  0.000  ...
# 10  2009-10  30.0  PHI    NBA  PF  76.0  2297.0  15.7  0.518  0.001  ...
# 11  2010-11  31.0  PHI    NBA  PF  81.0  2809.0  18.5  0.553  0.001  ...
# ...

# %%
from selenium import webdriver
from BeautifulSoup import BeautifulSoup
import pandas as pd
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")

driver.get("https://www.basketball-reference.com/leagues/NBA_2019_rookies.html")

content = driver.page_source
soup = BeautifulSoup(content)
for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
    a
